# %% [markdown]
# # Named Entity Recognition

# %% [markdown]
# Named Entity Recognition (NER) in NLP focuses on identifying and categorizing important information known as entities in text. These entities can be names of people, places, organizations, dates, etc. It helps in transforming unstructured text into structured information which helps in tasks like text summarization, knowledge graph creation and question answering.
#
# Understanding Named Entity Recognition
# NER helps in detecting specific information and sort it into predefined categories. It plays an important role in enhancing other NLP tasks like part-of-speech tagging and parsing. Examples of Common Entity Types:
#
# * Person Names: Albert Einstein
# * Organizations: GeeksforGeeks
# * Locations: Paris
# * Dates and Times: 5th May 2025
# * Quantities and Percentages: 50%, $100

# %%
sentence="Trinamool Congress leader Mahua Moitra has moved the Supreme Court against her expulsion from the Lok Sabha over the cash-for-query allegations against her. Moitra was ousted from the Parliament last week after the Ethics Committee of the Lok Sabha found her guilty of jeopardising national security by sharing her parliamentary portal's login credentials with businessman Darshan Hiranandani"

# %%
import nltk
nltk.download('punkt') # for tokenization
nltk.download('averaged_perceptron_tagger_eng') # for POS tagging
nltk.download('maxent_ne_chunker') # for entity recognition
nltk.download('words') # for entity recognition
nltk.download('maxent_ne_chunker_tab') # additional required resource
# Out:
# [nltk_data] Downloading package punkt to C:\Users\PC/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\PC/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\PC/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to C:\Users\PC/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\PC/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
# convert to words
import nltk
word=nltk.word_tokenize(sentence)
print(word)
# Out:
# ['Trinamool', 'Congress', 'leader', 'Mahua', 'Moitra', 'has', 'moved', 'the', 'Supreme', 'Court', 'against', 'her', 'expulsion', 'from', 'the', 'Lok', 'Sabha', 'over', 'the', 'cash-for-query', 'allegations', 'against', 'her', '.', 'Moitra', 'was', 'ousted', 'from', 'the', 'Parliament', 'last', 'week', 'after', 'the', 'Ethics', 'Committee', 'of', 'the', 'Lok', 'Sabha', 'found', 'her', 'guilty', 'of', 'jeopardising', 'national', 'security', 'by', 'sharing', 'her', 'parliamentary', 'portal', "'s", 'login', 'credentials', 'with', 'businessman', 'Darshan', 'Hiranandani']

# %%
tag_element=nltk.pos_tag(word)

# %%
print(tag_element)
# Out:
# [('Trinamool', 'NNP'), ('Congress', 'NNP'), ('leader', 'NN'), ('Mahua', 'NNP'), ('Moitra', 'NNP'), ('has', 'VBZ'), ('moved', 'VBN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('against', 'IN'), ('her', 'PRP$'), ('expulsion', 'NN'), ('from', 'IN'), ('the', 'DT'), ('Lok', 'NNP'), ('Sabha', 'NNP'), ('over', 'IN'), ('the', 'DT'), ('cash-for-query', 'JJ'), ('allegations', 'NNS'), ('against', 'IN'), ('her', 'PRP'), ('.', '.'), ('Moitra', 'NNP'), ('was', 'VBD'), ('ousted', 'VBN'), ('from', 'IN'), ('the', 'DT'), ('Parliament', 'NNP'), ('last', 'JJ'), ('week', 'NN'), ('after', 'IN'), ('the', 'DT'), ('Ethics', 'NNP'), ('Committee', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Lok', 'NNP'), ('Sabha', 'NNP'), ('found', 'VBD'), ('her', 'PRP$'), ('guilty', 'JJ'), ('of', 'IN'), ('jeopardising', 'VBG'), ('national', 'JJ'), ('security', 'NN'), ('by', 'IN'), ('sharing', 'VBG'), ('her', 'PRP$'), ('parliamentary', 'JJ'), ('portal', 'NN'), ("'s", 'POS'), ('login', 'NN'), ('credentials', 'NNS'), ('with', 'IN'), ('businessman', 'NN'), ('Darshan', 'NNP'), ('Hiranandani', 'NNP')]

# %%
nltk.ne_chunk(tag_element)
# Out:
# Tree('S', [Tree('PERSON', [('Trinamool', 'NNP')]), Tree('ORGANIZATION', [('Congress', 'NNP')]), ('leader', 'NN'), Tree('PERSON', [('Mahua', 'NNP'), ('Moitra', 'NNP')]), ('has', 'VBZ'), ('moved', 'VBN'), ('the', 'DT'), Tree('ORGANIZATION', [('Supreme', 'NNP'), ('Court', 'NNP')]), ('against', 'IN'), ('her', 'PRP$'), ('expulsion', 'NN'), ('from', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('Lok', 'NNP'), ('Sabha', 'NNP')]), ('over', 'IN'), ('the', 'DT'), ('cash-for-query', 'JJ'), ('allegations', 'NNS'), ('against', 'IN'), ('her', 'PRP'), ('.', '.'), Tree('PERSON', [('Moitra', 'NNP')]), ('was', 'VBD'), ('ousted', 'VBN'), ('from', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('Parliament', 'NNP')]), ('last', 'JJ'), ('week', 'NN'), ('after', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('Ethics', 'NNP'), ('Committee', 'NNP')]), ('of', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('Lok', 'NNP'), ('Sabha', 'NNP')]), ('found', 'VBD'), ('her', 'PRP$'), ('guilty', 'JJ'), ('of', 'IN'), ('jeopardising', 'VBG'), ('national', 'JJ'), ('security', 'NN'), ('by', 'IN'), ('sharing', 'VBG'), ('her', 'PRP$'), ('parliamentary', 'JJ'), ('portal', 'NN'), ("'s", 'POS'), ('login', 'NN'), ('credentials', 'NNS'), ('with', 'IN'), ('businessman', 'NN'), Tree('PERSON', [('Darshan', 'NNP'), ('Hiranandani', 'NNP')])])
